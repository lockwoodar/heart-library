# %% [markdown]
# ```
# conda create -n heart-cf-stats -c conda-forge python=3.11
# conda activate heart-cf-stats
# pip install -r requirements.txt
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load csv data from modified condastats output
# condastats overall heart-library --monthly
# data is broken and poorly formatted, requires some hand editing but is easy to shape with awk

df_heart = pd.read_csv("heart_data.csv", delim_whitespace=True)
print(df_heart)
print("\n\n")

# change to art_data_full.csv for more statistics
df_art = pd.read_csv("art_data_full.csv", delim_whitespace=True)
print(df_art)
# Out:
#         pkg_name     time  count
# 0  heart-library  2024-07     36
# 1  heart-library  2024-08     71
# 2  heart-library  2024-09     54
# 3  heart-library  2024-10    322
# 4  heart-library  2024-11   1751
# 5  heart-library  2024-12    886
#
#
#
#    pkg_name     time  count
# 0       art  2020-07     39
# 1       art  2020-08     91
# 2       art  2020-09    106
# 3       art  2020-10    175
# 4       art  2020-11     55
# 5       art  2020-12     94
# 6       art  2021-01    153
# 7       art  2021-02    178
# 8       art  2021-03    564
# 9       art  2021-04    579
# 10      art  2021-05    529
# 11      art  2021-06    785
# 12      art  2021-07    658
# 13      art  2021-08    933
# 14      art  2021-09    865
# 15      art  2021-10   1021
# 16      art  2021-11    407
# 17      art  2021-12    500
# 18      art  2022-01    567
# 19      art  2022-02    363
# 20      art  2022-03    478
# 21      art  2022-04    314
# 22      art  2022-05    621
# ...

# %%
# convert cf data to datetime
df_heart["time"] = pd.to_datetime(df_heart["time"], format="%Y-%m")
df_art["time"] = pd.to_datetime(df_art["time"], format="%Y-%m")
print(df_heart)
print("\n\n")
print(df_art)
# Out:
#         pkg_name       time  count
# 0  heart-library 2024-07-01     36
# 1  heart-library 2024-08-01     71
# 2  heart-library 2024-09-01     54
# 3  heart-library 2024-10-01    322
# 4  heart-library 2024-11-01   1751
# 5  heart-library 2024-12-01    886
#
#
#
#    pkg_name       time  count
# 0       art 2020-07-01     39
# 1       art 2020-08-01     91
# 2       art 2020-09-01    106
# 3       art 2020-10-01    175
# 4       art 2020-11-01     55
# 5       art 2020-12-01     94
# 6       art 2021-01-01    153
# 7       art 2021-02-01    178
# 8       art 2021-03-01    564
# 9       art 2021-04-01    579
# 10      art 2021-05-01    529
# 11      art 2021-06-01    785
# 12      art 2021-07-01    658
# 13      art 2021-08-01    933
# 14      art 2021-09-01    865
# 15      art 2021-10-01   1021
# 16      art 2021-11-01    407
# 17      art 2021-12-01    500
# 18      art 2022-01-01    567
# 19      art 2022-02-01    363
# 20      art 2022-03-01    478
# ...

# %%
# Create HEART data plot
plt.figure(figsize=(10,6))
plt.plot(df_heart["time"], df_heart["count"], marker="o", linestyle="-")
plt.title("heart-library Monthly Downloads via Conda-Forge")
plt.xlabel("Month")
plt.ylabel("Number of Downloads")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Create ART-Core data plot
plt.figure(figsize=(10,6))
plt.plot(df_art["time"], df_art["count"], marker="o", linestyle="-")
plt.title("Adversarial-Robustness-Toolbox Monthly Downloads via Conda-Forge")
plt.xlabel("Month")
plt.ylabel("Number of Downloads")
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
